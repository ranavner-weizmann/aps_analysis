# %%
import numpy as np
import pandas as pd
import time
import torch

# %%
csv_path = 'ashdod_kala.csv'
flight_times = torch.load('../raw/drone/pom_timestamps.pt', map_location='cpu', weights_only=False)
flight_time_list = flight_times.to_list()

# %%
modiin_csv = pd.read_csv('modiin.csv')
modiin_csv.head()
# Out:
#                      0  EP_station_NO  EP_station_NO2  EP_station_NOX  \
# 0  2023-05-01 00:05:00            0.4             4.0             4.5
# 1  2023-05-01 00:10:00            0.4             3.9             4.5
# 2  2023-05-01 00:15:00            0.5             4.6             5.3
# 3  2023-05-01 00:20:00            0.4             3.6             4.2
# 4  2023-05-01 00:25:00            0.4             3.4             4.0
#
#    EP_station_O3  EP_station_PM10  EP_station_PM2.5  EP_station_RH  \
# 0          100.5             20.3               NaN            NaN
# 1           99.6             20.5               NaN            NaN
# 2           98.3             20.9               NaN            NaN
# 3           98.9             21.1               NaN            NaN
# 4          100.7             21.1               NaN            NaN
#
#    EP_station_SO2  EP_station_Temp  EP_station_WD  EP_station_WS  \
# 0             4.6              NaN          136.0            1.4
# ...

# %%
shamat_csv = pd.read_csv('shamat.csv')
shamat_csv.head()
# Out:
#              Timestamp  shamat_P  shamat_RH  shamat_T  shamat_T_ground  \
# 0  2023-05-01 00:00:00    1011.8       73.0      15.6             15.0
# 1  2023-05-01 00:10:00    1011.8       73.0      15.3             15.0
# 2  2023-05-01 00:20:00    1011.8       72.0      15.3             15.2
# 3  2023-05-01 00:30:00    1011.7       73.0      15.2             15.0
# 4  2023-05-01 00:40:00    1011.8       73.0      15.0             15.1
#
#    shamat_T_max  shamat_T_min  shamat_precipitation  shamat_wind_direction  \
# 0          15.6          15.4                   0.0                  130.0
# 1          15.4          15.2                   0.0                   96.0
# 2          15.3          15.2                   0.0                  102.0
# 3          15.3          15.1                   0.0                   99.0
# 4          15.1          15.0                   0.0                  107.0
#
#    shamat_wind_direction_std_dev  shamat_wind_gust_direction  \
# ...

# %%
shamat_t = torch.load('../station_tensors/shamat.pt')
tel_aviv_levinsky = torch.load('../station_tensors/tel_aviv_levinsky.pt')
